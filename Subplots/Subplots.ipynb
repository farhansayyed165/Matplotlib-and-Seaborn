# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = pd.read_csv('data_lang.csv')
ages = data['Age']
dev = data['All_Devs']
py = data['Python']
js = data['JavaScript']

# %%
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
## Plotting 2 line plots in different windows
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

plt.style.use('seaborn')

ax1.plot(ages,dev,label = 'All Dev Salaries', linestyle = '--', color='#444444')
ax2.plot(ages,py,label='Python Salaries')
ax2.plot(ages,js,label = 'JavaSript Salaries')


ax1.legend()
ax1.set_title('Median Salaries by Ages')
ax1.set_ylabel('Median Salary(USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary(USD)')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
fig.savefig('subplot_fig1.png')
fig.savefig('subplot_fig2.png')

# %%
fig, (ax3, ax4) = plt.subplots(ncols=1,nrows=2, sharex=True)

## Plotting 2 line plots in a same window as SUBPLOTS
plt.style.use('bmh')

ax3.plot(ages,dev,label = 'All Dev Salaries', linestyle = '--', color='#444444')
ax4.plot(ages,py,label='Python Salaries')
ax4.plot(ages,js,label = 'JavaSript Salaries')


ax3.legend()
ax3.set_title('Median Salaries by Ages')
ax3.set_ylabel('Median Salary(USD)')

ax4.legend()
ax4.set_xlabel('Ages')
ax4.set_ylabel('Median Salary(USD)')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
